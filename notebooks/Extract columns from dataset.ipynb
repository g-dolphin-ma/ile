# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ile.io

# %%
dataset = ile.io.NHAMCS(2020)

# %%
columns = []

# RFV
columns += [f'RFV{i}' for i in range(1, 6)]

# RFV3D
columns += [f'RFV{i}3D' for i in range(1, 6)]

# CAUSE
columns += [f'CAUSE{i}' for i in range(1, 4)]

# %%
dataset.data[columns]
# Out:
#         RFV1   RFV2   RFV3   RFV4   RFV5  RFV13D  RFV23D  RFV33D  RFV43D  \
# 0      28000  10100     -9     -9     -9    2800    1010       0       0
# 1      16500  16601  15450     -9     -9    1650    1660    1545       0
# 2      14850  14501  10100  14400  10601    1485    1450    1010    1440
# 3      19101  10601  10100  61000     -9    1910    1060    1010    6100
# 4      14850  14501  10100  15702     -9    1485    1450    1010    1570
# ...      ...    ...    ...    ...    ...     ...     ...     ...     ...
# 14855  10501     -9     -9     -9     -9    1050       0       0       0
# 14856  58154     -9     -9     -9     -9    5815       0       0       0
# 14857  15451     -9     -9     -9     -9    1545       0       0       0
# 14858  15451     -9     -9     -9     -9    1545       0       0       0
# 14859  59150     -9     -9     -9     -9    5915       0       0       0
#
#        RFV53D CAUSE1 CAUSE2 CAUSE3
# 0           0     -9     -9     -9
# ...

# %%
dataset.value_labels['SEXF']
# Out:
# {1: 'Female', 2: 'Male'}

# %%
from ile.dataset import NHAMCSDataset
tds = NHAMCSDataset(2020)

# %%
tds._x.shape
# Out:
# (14860, 3829)
